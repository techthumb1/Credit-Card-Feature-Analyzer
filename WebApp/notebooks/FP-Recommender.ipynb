# %% [markdown]
# <div style="padding:20px;
#             color:#FFC300;
#             margin:0;
#             font-size:250%;
#             border-width: 1px;
#             border-style: solid;
#             text-align:center;
#             display:fill;
#             border-radius:5px;
#             background-color:#3474eb;
#             overflow:hidden;
#             font-family: Trebuchet MS;
#             font-weight:600">Fraud Protection Recommender System </div>
#
# <center>
#
# </center>

# %% [markdown]
# The recommender system will market to customers who have a higher likelihood of being a victim of fraud, due to some of the following reasons:
# - Substantial volume of daily transactions
# - Large transaction amounts
# - Transactions in a different country than the customer's home - country
# - Transactions in a different state than the customer's home  state
# - Online transactions

# %% [markdown]
# ####  1. Importing Libraries <a class='anchor' id='images'></a>

# %%
import pandas as pd

# %%
# Read in the data
"""Toy data for quick testing"""
df = pd.read_csv('/Users/jasonrobinson/Desktop/Credit-Card-Feature-Analyzer/WebApp/data/transactions.csv')

# %%
# First five rows
df.head()
# Out:
#    User  Card  Year  Month  Day   Time   Amount           Use Chip  \
# 0     0     0  2002      9    1  06:21  $134.09  Swipe Transaction
# 1     0     0  2002      9    1  06:42   $38.48  Swipe Transaction
# 2     0     0  2002      9    2  06:22  $120.34  Swipe Transaction
# 3     0     0  2002      9    2  17:45  $128.95  Swipe Transaction
# 4     0     0  2002      9    3  06:23  $104.71  Swipe Transaction
#
#          Merchant Name  Merchant City Merchant State      Zip   MCC Errors?  \
# 0  3527213246127876953       La Verne             CA  91750.0  5300     NaN
# 1  -727612092139916043  Monterey Park             CA  91754.0  5411     NaN
# 2  -727612092139916043  Monterey Park             CA  91754.0  5411     NaN
# 3  3414527459579106770  Monterey Park             CA  91754.0  5651     NaN
# 4  5817218446178736267       La Verne             CA  91750.0  5912     NaN
#
#   Is Fraud?
# 0        No
# 1        No
# 2        No
# 3        No
# 4        No

# %%
# Shape of the data
df.shape
# Out:
# (19963, 15)

# %%
df[df.Card!=1]
# Out:
#        User  Card  Year  Month  Day   Time   Amount           Use Chip  \
# 0         0     0  2002      9    1  06:21  $134.09  Swipe Transaction
# 1         0     0  2002      9    1  06:42   $38.48  Swipe Transaction
# 2         0     0  2002      9    2  06:22  $120.34  Swipe Transaction
# 3         0     0  2002      9    2  17:45  $128.95  Swipe Transaction
# 4         0     0  2002      9    3  06:23  $104.71  Swipe Transaction
# ...     ...   ...   ...    ...  ...    ...      ...                ...
# 19958     0     4  2009      2   12  13:03    $9.71  Swipe Transaction
# 19959     0     4  2009      2   22  11:58   $27.94  Swipe Transaction
# 19960     0     4  2009      2   24  16:53   $13.97  Swipe Transaction
# 19961     0     4  2009      3   29  16:30   $14.27  Swipe Transaction
# 19962     0     4  2009      3   31  13:17   $13.55  Swipe Transaction
#
#              Merchant Name  Merchant City Merchant State      Zip   MCC  \
# ...

# %%
df.Card.unique()
# Out:
# array([0, 1, 2, 3, 4])
